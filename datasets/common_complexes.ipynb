# %% [markdown]
# Check which directories are/not in PDBBind_preprocessed vs CysDB to determine whether preprocessing steps done with PDBBind_Processed_all (by EquiBind authors) need to be done for CysDB proteins too

# %%
import os

set1 = set(os.listdir('/home/ymanasa/turbo/ymanasa/opt/DiffDockL-Cov/data/PDBBind_processed'))
set2 = set(os.listdir('/home/ymanasa/turbo/ymanasa/opt/DiffDockL-Cov/data/CovPDB_complexes'))

common_dirs = set1.intersection(set2)
print(len(common_dirs))
print(len(set1),len(set2))
common_dirs
# Out:
# 122
# 2619 2261
# {'1a3e',
#  '1a46',
#  '1a5g',
#  '1a61',
#  '1ad8',
#  '1aht',
#  '1auj',
#  '1awf',
#  '1ayu',
#  '1ayv',
#  '1b5g',
#  '1bgo',
#  '1bio',
#  '1bmq',
#  '1c3b',
#  '1doj',
#  '1e34',
#  '1e37',
#  '1eas',
#  '1eat',
#  '1ero',
#  '1erq',
#  '1exw',
#  '1f28',
#  '1f7b',
#  '1fsw',
#  '1fsy',
#  '1g37',
#  '1ga9',
#  '1gbt',
#  '1gmy',
#  '1gzg',
#  '1h8y',
#  '1hbj',
#  '1hvy',
#  '1i8j',
#  '1iem',
#  '1inc',
#  '1k2i',
#  '1kds',
#  '1kdw',
#  '1ke0',
#  '1ke3',
#  '1l6s',
#  '1lhc',
#  '1lhd',
#  '1lhe',
#  '1lhf',
#  '1lhg',
#  '1llb',
#  '1mem',
#  '1mns',
#  '1mpl',
#  '1ms6',
#  '1mxo',
#  '1my8',
#  '1nc6',
#  '1nlj',
#  '1nms',
#  '1no9',
#  '1npz',
#  '1nqc',
#  '1nxy',
#  '1ny0',
#  '1nym',
#  '1nyy',
#  '1o41',
#  '1o43',
#  '1o45',
#  '1o4a',
#  '1o4d',
#  '1o4e',
#  '1o4i',
#  '1o4k',
#  '1ong',
#  '1onh',
#  '1p01',
#  '1p02',
#  '1p03',
#  '1p05',
#  '1p06',
#  '1p10',
#  '1pi4',
#  '1pi5',
#  '1q6k',
#  '1qcp',
#  '1qfs',
#  '1qhr',
#  '1qj1',
# ...
